# %% [markdown]
# <a href="https://colab.research.google.com/github/gowrilvinod/Gemini_Text_Summarization/blob/main/gemini2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Libraries Required
# !pip install langchain-huggingface
## For API Calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install  bitsandbytes
# !pip install langchain

# %%
import os

# %%
from huggingface_hub import hf_hub_download
from langchain_huggingface import HuggingFacePipeline

# %%
os.environ["HUGGING_FACE_API_KEY"] = "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"

HUGGING_FACE_API_KEY = os.environ.get("HUGGING_FACE_API_KEY")

if HUGGING_FACE_API_KEY:
    print("Hugging Face API key is set.")
else:
    print("Hugging Face API key is not set.")
# Out:
# Hugging Face API key is set.

# %%
model_id= "failspy/Phi-3-mini-4k-geminified"

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(model_id, trust_remote_code=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/3.17k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/568 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/904 [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/failspy/Phi-3-mini-4k-geminified:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.8k [00:00<?, ?B/s]
# ...

# %%
model_id = "describeai/gemini"

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM , pipeline

tokenizer = AutoTokenizer.from_pretrained("describeai/gemini")
model = AutoModelForSeq2SeqLM.from_pretrained("describeai/gemini")

# %%
filenames =["config.json" , "pytorch_model.bin" , "special_tokens_map.json" , "spiece.model" , "tokenizer.json" , "tokenizer_config.json"]

# %%
for file in filenames:
   model_path = hf_hub_download(repo_id=model_id, filename=file, token=HUGGING_FACE_API_KEY)

# %%
print(model_path)
# Out:
# /root/.cache/huggingface/hub/models--describeai--gemini/snapshots/aa5c52e95888664ccbb83d868de3b7b26ae123c3/tokenizer_config.json

# %%
pipe=pipeline("text2text-generation",model=model,tokenizer=tokenizer,max_new_tokens=500)

# %%
input_text = "generate summary: Gemini is a methodology pioneered by Hugging Face, focusing on optimizing machine learning models for efficiency and performance across natural language processing tasks. It involves fine-tuning models with techniques like model compression and hyperparameter optimization to achieve state-of-the-art results while maintaining computational efficiency. Gemini models are versatile, scalable, and adaptable to various NLP applications, including text classification, summarization, translation, and more complex tasks requiring nuanced language understanding and generation. This approach underscores Hugging Face's commitment to advancing AI capabilities through iterative improvement and customization of pre-trained models."

generated_text = pipe(input_text)

print(generated_text)
# Out:
# [{'generated_text': 'This code is creating a new methodology pioneered by Hugging Face. It involves optimizing machine learning models for efficiency and performance across natural language processing tasks.'}]
